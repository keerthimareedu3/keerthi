# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthimareedu3/keerthi/blob/main/Computer_Vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-05d57735-b881-4a4a-bf60-4a163b436612" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05d57735-b881-4a4a-bf60-4a163b436612">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
image=Image.open("rose.jpg")
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c7f6c249-5a6a-4567-8d6c-b550ed7e1b0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7f6c249-5a6a-4567-8d6c-b550ed7e1b0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
image=Image.open("radhekrishna.jpg")
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-2a97f138-d140-4319-888a-920696975a0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a97f138-d140-4319-888a-920696975a0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
image=Image.open("radhekrishna.jpg").convert("L")
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-bdd87dce-b371-43a0-8183-1db5883284f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdd87dce-b371-43a0-8183-1db5883284f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
image=Image.open("radhekrishna.jpg")
image.thumbnail((500,500))
plt.imshow(image)
plt.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-de471344-8fb0-4b54-b319-989c0c17ab08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de471344-8fb0-4b54-b319-989c0c17ab08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
image=Image.open("rose.jpg")
image1 = image.transpose(Image.FLIP_TOP_BOTTOM)
image2=image.transpose(Image.FLIP_LEFT_RIGHT)

plt.imshow(image)
plt.title("Original")
plt.axis("off")
plt.show()
plt.imshow(image1)
plt.title("TOP_BOTTOM_FLIP")
plt.axis("off")
plt.show()
plt.imshow(image2)
plt.title("LEFT_RIGHT_FLIP")
plt.axis("off")
plt.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-92095800-7262-4521-9faa-56a2fa66d135" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92095800-7262-4521-9faa-56a2fa66d135">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
from matplotlib import pyplot
image=Image.open("bird.jpg")
pyplot.subplot(411)
pyplot.imshow(image)
pyplot.subplot(412)
pyplot.imshow(image.rotate(45))
pyplot.subplot(413)
pyplot.imshow(image.rotate(90))
pyplot.subplot(414)
pyplot.imshow(image.rotate(65))

pyplot.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-56d722cd-1794-4575-8ccf-4efe7db1bffe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-56d722cd-1794-4575-8ccf-4efe7db1bffe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.utils import load_img
import matplotlib.pyplot as plt

img = load_img("bird.jpg")

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-72ca6d89-00d7-4dbb-bff9-0d108160dcb7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72ca6d89-00d7-4dbb-bff9-0d108160dcb7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from numpy import expand_dims
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

img = load_img("bird.jpg")
data = img_to_array(img)
samples = expand_dims(data, 0)

datagen = ImageDataGenerator(width_shift_range = [-80, 80])

it = datagen.flow(samples, batch_size = 1)

for i in range(4):

 pyplot.subplot(330 + 1 + i)
 batch = next(it)
 image = batch[0].astype("uint8")
 pyplot.imshow(image)
pyplot.axis("off")
pyplot.show()

# %%
from google.colab import files
uploade=files.upload()
# Out:
#      <input type="file" id="files-7cd218d5-9e83-4307-9314-6eb405fc189e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7cd218d5-9e83-4307-9314-6eb405fc189e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from numpy import expand_dims
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
img=load_img("bird.jpg")
data=img_to_array(img)
samples=expand_dims(data,0)
datagen=ImageDataGenerator(height_shift_range=10)
it = datagen.flow(samples, batch_size = 1)
for i in range(25):
  pyplot.subplot(5,5,1 + i)
  batch = next(it)
  image = batch[0].astype("uint8")
  pyplot.imshow(image)

pyplot.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c9072576-d884-4d7c-ba67-f4f128a7ec9e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9072576-d884-4d7c-ba67-f4f128a7ec9e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from numpy import expand_dims
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

img = load_img("bird.jpg")
data = img_to_array(img)

sample = expand_dims(data, 0)

datagen = ImageDataGenerator(horizontal_flip=True)
it = datagen.flow(sample, batch_size=1)

for i in range(16):
    plt.subplot(4, 4, i + 1)
    batch = next(it)
    image = batch[0].astype("uint8")
    plt.imshow(image)
    plt.axis("off")

plt.show()

# %%
from numpy import expand_dims
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

img = load_img("bird.jpg")
data = img_to_array(img)

sample = expand_dims(data, 0)

datagen = ImageDataGenerator(rotation_range=65)
it = datagen.flow(sample, batch_size=1)

for i in range(16):
    plt.subplot(4, 4, i + 1)
    batch = next(it)
    image = batch[0].astype("uint8")
    plt.imshow(image)
    plt.axis("off")

plt.show()

# %%
from numpy import expand_dims
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

img = load_img("bird.jpg")
data = img_to_array(img)

sample = expand_dims(data, 0)

datagen = ImageDataGenerator(brightness_range = [0.9, 9.0])
it = datagen.flow(sample, batch_size=1)

for i in range(9):
    plt.subplot(3, 3, i + 1)
    batch = next(it)
    image = batch[0].astype("uint8")
    plt.imshow(image)
    plt.axis("off")

plt.show()

# %%
from numpy import expand_dims
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

img = load_img("bird.jpg")
data = img_to_array(img)

sample = expand_dims(data, 0)

datagen = ImageDataGenerator(brightness_range = [1.5, 0.1])
it = datagen.flow(sample, batch_size=1)

for i in range(9):
    plt.subplot(3, 3, i + 1)
    batch = next(it)
    image = batch[0].astype("uint8")
    plt.imshow(image)
    plt.axis("off")

plt.show()

# %%
from numpy import expand_dims
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

img = load_img("bird.jpg")
data = img_to_array(img)

sample = expand_dims(data, 0)

datagen = ImageDataGenerator(zoom_range = [0.14, 9.0])
it = datagen.flow(sample, batch_size=1)

for i in range(9):
    plt.subplot(3, 3, i + 1)
    batch = next(it)
    image = batch[0].astype("uint8")
    plt.imshow(image)
    plt.axis("off")

plt.show()

# %%
from numpy import expand_dims
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot

img = load_img("bird.jpg")
data = img_to_array(img)
samples = expand_dims(data, 0)

datagen = ImageDataGenerator(zoom_range = [1.1,0.2])

it = datagen.flow(samples, batch_size = 1)

for i in range(9):
  pyplot.subplot(330 + 1 + i)
  batch = next(it)
  image = batch[0].astype("uint8")
  pyplot.imshow(img)
plt.show()

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-615d7249-7e59-4087-a614-095bfc27fb4e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-615d7249-7e59-4087-a614-095bfc27fb4e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('rose.jpg')
edges = cv2.Canny(img, 100, 200, 3, L2gradient = True)

plt.figure()
plt.title('')
plt.imsave('dancing-spider-canny.png', edges, cmap = 'gray',
format='png')
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(img)
plt.axis("off")
plt.show()
plt.subplot(1, 2, 2)
plt.title("Canny Edge Image")
plt.imshow(edges, cmap="gray")
plt.axis("off")
plt.show()
