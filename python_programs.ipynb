# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthimareedu3/keerthi/blob/main/python_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DAILY TASKS**

# %% [markdown]
# # DAY-O1(27/11/2025)

# %%
firstname="sathya"
secondname="Technology"
fullname=firstname+secondname
print(fullname)
# Out:
# sathyaTechnology

# %%
a=5
b=7
c=a+b
print("sum of a,b:",c)
# Out:
# sum of a,b: 12

# %%
a=5.6
b=10.5
print("The sum of a,b is:",a+b)
# Out:
# The sum of a,b is: 16.1

# %%
a=20
b=2.5
c=a-b
print("The value is:",c)
# Out:
# The value is: 17.5

# %%
vishu_sal=650000
monthly_sal=650000/12
print("monthly_sal is:",monthly_sal)
# Out:
# monthly_sal is: 54166.666666666664

# %%
monthly_sal=34500.0
annual_sal=monthly_sal*12
print("The annual_sal is:",annual_sal)
# Out:
# The annual_sal is: 414000.0

# %%
pizza_cost=345.60
ordered_pizza=3
billamount=pizza_cost*ordered_pizza
service_charges=20
tips=30
totalamount=billamount+service_charges+tips
print("The total bill amount:",totalamount)
# Out:
# The total bill amount: 1086.8000000000002

# %%
sub1=92
sub2=98
sub3=99
total=sub1+sub2+sub3
average_marks=total/3
print("Total is:",total)
print("Average_marks:",average_marks)
# Out:
# Total is: 289
# Average_marks: 96.33333333333333

# %%
celsius=32
fahrenheit=(celsius*9/5)+32
print("The fahrenheit is:",fahrenheit)
# Out:
# The fahrenheit is: 89.6

# %%
fahrenheit=102
celsius=(fahrenheit-32)*5/9
print("The celsius is:",celsius)
# Out:
# The celsius is: 38.888888888888886

# %%
principal=500000
rate=7.8
time=5
interest=(principal*rate*time)/100
final_amount=principal+interest
print("Interest Amount is:",interest)
print("Final Amount is:",final_amount)
# Out:
# Interest Amount is: 195000.0
# Final Amount is: 695000.0

# %%
k=5
l=8
m=k
print("The value of m:",m)
# Out:
# The value of m: 5

# %%
x=6
y=x+9
print("The value of y:",y)
# Out:
# The value of y: 15

# %%
p=43
q=p
print("The value of q:",q)
# Out:
# The value of q: 43

# %%
distance_reading1=11236
distance_reading2=11494
distance_traveled_meters=distance_reading2-distance_reading1
distance_traveled_km=distance_traveled_meters/1000
print("She travelled distance is :",distance_traveled_km)
# Out:
# She travelled distance is : 0.258

# %%
item_cost1=220*3
item_cost2=360*2
tip=20
total_amount=item_cost1+item_cost2+tip
sharing_amount=total_amount/3
print("The total amount is :",total_amount)
print("The sharing amount is :",sharing_amount)
# Out:
# The total amount is : 1400
# The sharing amount is : 466.6666666666667

# %%
milk_bill=930.0
per_day=930.0/31
leave_amount=per_day*4
total_amount=milk_bill-leave_amount
print("The total milk bill in march is:",total_amount)
# Out:
# The total milk bill in march is: 810.0

# %%
attended=94
total_days=120
percentage=(attended/total_days)*100
print("percentage of attendence:",percentage)
# Out:
# percentage of attendence: 78.33333333333333

# %%
per_day=6
one_month=31*6
cost=20
total_bill=one_month*cost
print("The total bill in august is:",total_bill)
# Out:
# The total bill in august is: 3720

# %%
petrol_cost=108.96
total_money=300
liters=total_money/petrol_cost
print("petrol we got is:",liters)
# Out:
# petrol we got is: 2.7533039647577096

# %%
cost1=1150
cost2=1680
profit=cost2-cost1
print("profit is:",profit)
# Out:
# profit is: 530

# %%
product_cost=200
gst=20
gst_amount=(product_cost*20)/100
total_bill=product_cost+gst_amount
print("The total bill is:",total_bill)
# Out:
# The total bill is: 240.0

# %%
pizza_cost=326.50
ordered_pizza=3
total_amount=pizza_cost*ordered_pizza
discount_amount=20/100
total_bill=total_amount-discount_amount
print("The total bill amount is:",total_bill)
# Out:
# The total bill amount is: 979.3

# %%
salary=30000
pf=12
tax=8
pf_deduction=salary/pf
tax_deduction=salary/tax
net_salary=salary-pf_deduction-tax_deduction
print("The monthly salary is:",net_salary)
# Out:
# The monthly salary is: 23750.0

# %%
prinicipal=500000
rate=11.4
time=4
interest_amount=(prinicipal*rate*time)/100
final_amount=prinicipal+interest_amount
months=4*12
emi=final_amount/months
print("The Interst is:",interest_amount)
print("The Final_amount is:",final_amount)
print("The EMI is :",emi)
# Out:
# The Interst is: 228000.0
# The Final_amount is: 728000.0
# The EMI is : 15166.666666666666

# %%
last_month_reading=2234
current_month_reading=2456
cost_per_unit=3.46
tax_per_unit=0.046
services_charges=30
units=current_month_reading-last_month_reading
bill_amount=(units*cost_per_unit)+(units*tax_per_unit)+services_charges
print("Units consumed:",units)
print("Total electricity bill:",bill_amount)
# Out:
# Units consumed: 222
# Total electricity bill: 808.332

# %%
start_reading=11236
end_reading=11494
distance=end_reading-start_reading
print("Distance travelled is:",distance)
# Out:
# Distance travelled is: 258
