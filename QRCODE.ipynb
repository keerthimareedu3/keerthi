# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthimareedu3/keerthi/blob/main/QRCODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qrcode[pil]
# Out:
# Collecting qrcode[pil]
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pillow>=9.1.0 in /usr/local/lib/python3.12/dist-packages (from qrcode[pil]) (11.3.0)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2

# %%
import qrcode
from PIL import Image
from IPython.display import display
data="http//www.google.com"
qr=qrcode.QRCode(
    version=1,
    box_size=10,
    border=5
   )
qr.add_data(data)
qr.make(fit=True)
img=qr.make_image(fill="black",back_color="white")
display(img)
img.save("my_qrcode.png")

# %%
import qrcode
from IPython.display import display
phone_number="tel.+917780633752"
qr=qrcode.QRCode(
    version=None,
    box_size=15,
    border=4
)
qr.add_data(phone_number)
qr.make(fit=True)

img=qr.make_image(fill_color="black",back_color="white")
display(img)
img.save("phone_qrcode.png")

# %%
# !pip install qrcode[pil]
# Out:
# Requirement already satisfied: qrcode[pil] in /usr/local/lib/python3.12/dist-packages (8.2)
# Requirement already satisfied: pillow>=9.1.0 in /usr/local/lib/python3.12/dist-packages (from qrcode[pil]) (11.3.0)

# %%
import qrcode
from IPython.display import display
name="keerthi mareedu"
phone="+91778033752"
location="hyderabad"
data=f'''
BEGIN:VCARD
VERSION:3.0
FN:{name}
TEL:{phone}
ADR:{location}
END:VCARD
'''
qr=qrcode.QRCode(
   version=None,
   box_size=12,
   border=4
)
qr.add_data(data)
qr.make(fit=True)
img=qr.make_image(fill_color="black",back_color="white")
display(img)
img.save("contact_qrcode.png")

# %%
from google.colab import files
files.download("contact_qrcode.png")

# %%
import qrcode
from IPython.display import display
from google.colab import files
photo_link="https://i.pinimg.com/736x/d2/41/63/d24163bef0ea7a52ce7dda98e3a3ae0a.jpg"
qr=qrcode.QRCode(
    version=None,
    box_size=12,
    border=4
)
qr.add_data(photo_link)
qr.make(fit=True)
img=qr.make_image(fill_color="black",back_color="white")
display(img)
img.save("photo_qrcode.png")
files.download("photo_qrcode.png")

# %%
import qrcode
from IPython.display import display
from google.colab import files
photo_link="https://i.pinimg.com/736x/55/66/01/556601ac4bf0a7204397b524e84d886e.jpg"
qr=qrcode.QRCode(
    version=None,
    box_size=12,
    border=4
)
qr.add_data(photo_link)
qr.make(fit=True)
img=qr.make_image(fill_color="black",back_color="white")
display(img)
img.save("photo_qrcode.png")
files.download("photo_qrcode.png")
